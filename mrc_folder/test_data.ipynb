# %%
import pandas as pd
from skimpy import skim
import warnings

# %%
pd.set_option('display.max_columns', None)
pd.set_option("display.float_format", lambda x: f"{x :.2f}")
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MaskiVal/DataSets/main/kidney_disease.csv')
df.head()
# Out:
#    id   age    bp   sg   al   su     rbc        pc         pcc          ba  \
# 0   0 48.00 80.00 1.02 1.00 0.00     NaN    normal  notpresent  notpresent
# 1   1  7.00 50.00 1.02 4.00 0.00     NaN    normal  notpresent  notpresent
# 2   2 62.00 80.00 1.01 2.00 3.00  normal    normal  notpresent  notpresent
# 3   3 48.00 70.00 1.00 4.00 0.00  normal  abnormal     present  notpresent
# 4   4 51.00 80.00 1.01 2.00 0.00  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm cad appet   pe  \
# 0 121.00 36.00 1.20    NaN  NaN 15.40  44  7800  5.2  yes  yes  no  good   no
# 1    NaN 18.00 0.80    NaN  NaN 11.30  38  6000  NaN   no   no  no  good   no
# 2 423.00 53.00 1.80    NaN  NaN  9.60  31  7500  NaN   no  yes  no  poor   no
# 3 117.00 56.00 3.80 111.00 2.50 11.20  32  6700  3.9  yes   no  no  poor  yes
# 4 106.00 26.00 1.40    NaN  NaN 11.60  35  7300  4.6   no   no  no  good   no
#
#    ane classification
# 0   no            ckd
# 1   no            ckd
# 2  yes            ckd
# 3  yes            ckd
# 4   no            ckd

# %%
df.shape
# Out:
# (400, 26)

# %%
df.columns = ['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia', 'class']
df.head()
# Out:
#    id   age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0   0 48.00           80.00              1.02     1.00   0.00             NaN
# 1   1  7.00           50.00              1.02     4.00   0.00             NaN
# 2   2 62.00           80.00              1.01     2.00   3.00          normal
# 3   3 48.00           70.00              1.00     4.00   0.00          normal
# 4   4 51.00           80.00              1.01     2.00   0.00          normal
#
#    pus_cell pus_cell_clumps    bacteria  blood_glucose_random  blood_urea  \
# 0    normal      notpresent  notpresent                121.00       36.00
# 1    normal      notpresent  notpresent                   NaN       18.00
# 2    normal      notpresent  notpresent                423.00       53.00
# 3  abnormal         present  notpresent                117.00       56.00
# 4    normal      notpresent  notpresent                106.00       26.00
#
#    serum_creatinine  sodium  potassium  haemoglobin packed_cell_volume  \
# 0              1.20     NaN        NaN        15.40                 44
# 1              0.80     NaN        NaN        11.30                 38
# 2              1.80     NaN        NaN         9.60                 31
# 3              3.80  111.00       2.50        11.20                 32
# 4              1.40     NaN        NaN        11.60                 35
#
#   white_blood_cell_count red_blood_cell_count hypertension diabetes_mellitus  \
# 0                   7800                  5.2          yes               yes
# 1                   6000                  NaN           no                no
# 2                   7500                  NaN           no               yes
# 3                   6700                  3.9          yes                no
# 4                   7300                  4.6           no                no
#
#   coronary_artery_disease appetite peda_edema aanemia class
# 0                      no     good         no      no   ckd
# 1                      no     good         no      no   ckd
# 2                      no     poor         no     yes   ckd
# 3                      no     poor        yes     yes   ckd
# 4                      no     good         no      no   ckd

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 400    │ │ string      │ 14    │                                                          │
# │ │ Number of columns │ 26     │ │ float64     │ 11    │                                                          │
# │ └───────────────────┴────────┘ │ int32       │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name           ┃ NA  ┃ NA %   ┃ mean    ┃ sd       ┃ p0    ┃ p25   ┃ p50   ┃ p75   ┃ p100  ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━┩  │
# │ │ id                    │   0 │      0 │   199.5 │    115.6 │     0 │ 99.75 │ 199.5 │ 299.2 │   399 │ ▇▇▇▇▇▇ │  │
# │ │ age                   │   9 │   2.25 │   51.48 │    17.17 │     2 │    42 │    55 │  64.5 │    90 │ ▁▂▅▇▇▁ │  │
# │ │ blood_pressure        │  12 │      3 │   76.47 │    13.68 │    50 │    70 │    80 │    80 │   180 │  ▇▇▁   │  │
# │ │ specific_gravity      │  47 │  11.75 │   1.017 │ 0.005717 │ 1.005 │  1.01 │  1.02 │  1.02 │ 1.025 │ ▁▆ ▆▇▆ │  │
# │ │ albumin               │  46 │   11.5 │   1.017 │    1.353 │     0 │     0 │     0 │     2 │     5 │ ▇▂▂▂▁  │  │
# │ │ sugar                 │  49 │  12.25 │  0.4501 │    1.099 │     0 │     0 │     0 │     0 │     5 │   ▇    │  │
# │ │ blood_glucose_random  │  44 │     11 │     148 │    79.28 │    22 │    99 │   121 │   163 │   490 │  ▃▇▂▁  │  │
# │ │ blood_urea            │  19 │   4.75 │   57.43 │     50.5 │   1.5 │    27 │    42 │    66 │   391 │  ▇▂▁   │  │
# │ │ serum_creatinine      │  17 │   4.25 │   3.072 │    5.741 │   0.4 │   0.9 │   1.3 │   2.8 │    76 │   ▇    │  │
# │ │ sodium                │  87 │  21.75 │   137.5 │    10.41 │   4.5 │   135 │   138 │   142 │   163 │     ▅▇ │  │
# │ │ potassium             │  88 │     22 │   4.627 │    3.194 │   2.5 │   3.8 │   4.4 │   4.9 │    47 │   ▇    │  │
# │ │ haemoglobin           │  52 │     13 │   12.53 │    2.913 │   3.1 │  10.3 │ 12.65 │    15 │  17.8 │  ▁▅▇▇▅ │  │
# │ └───────────────────────┴─────┴────────┴─────────┴──────────┴───────┴───────┴───────┴───────┴───────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                         ┃ NA      ┃ NA %       ┃ words per row           ┃ total words         ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ red_blood_cells                     │     152 │         38 │                    0.62 │                 248 │  │
# │ │ pus_cell                            │      65 │      16.25 │                    0.84 │                 335 │  │
# │ │ pus_cell_clumps                     │       4 │          1 │                    0.99 │                 396 │  │
# │ │ bacteria                            │       4 │          1 │                    0.99 │                 396 │  │
# │ │ packed_cell_volume                  │      70 │       17.5 │                    0.82 │                 330 │  │
# │ │ white_blood_cell_count              │     105 │      26.25 │                    0.74 │                 295 │  │
# │ │ red_blood_cell_count                │     130 │       32.5 │                    0.68 │                 270 │  │
# │ │ hypertension                        │       2 │        0.5 │                    0.99 │                 398 │  │
# │ │ diabetes_mellitus                   │       2 │        0.5 │                       1 │                 399 │  │
# │ │ coronary_artery_disease             │       2 │        0.5 │                    0.99 │                 398 │  │
# │ │ appetite                            │       1 │       0.25 │                       1 │                 399 │  │
# │ │ peda_edema                          │       1 │       0.25 │                       1 │                 399 │  │
# │ │ aanemia                             │       1 │       0.25 │                       1 │                 399 │  │
# │ │ class                               │       0 │          0 │                       1 │                 400 │  │
# │ └─────────────────────────────────────┴─────────┴────────────┴─────────────────────────┴─────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
# converting necessary columns to numerical type

df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'], errors='coerce')
df['white_blood_cell_count'] = pd.to_numeric(df['white_blood_cell_count'], errors='coerce')
df['red_blood_cell_count'] = pd.to_numeric(df['red_blood_cell_count'], errors='coerce')

# %%
# Extracting categorical and numerical columns

cat_cols = [col for col in df.columns if df[col].dtype == 'object']
num_cols = [col for col in df.columns if df[col].dtype != 'object']

# %%
# looking at unique values in categorical columns

for col in cat_cols:
    print(f"{col} has {df[col].unique()} values\n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# peda_edema has ['no' 'yes' nan] values
#
# aanemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'ckd\t' 'notckd'] values
